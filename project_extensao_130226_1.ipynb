# %% [markdown]
# <a href="https://colab.research.google.com/github/deveveryday/data_science_jobs_and_salary/blob/main/project_extensao_130226_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛢️ 1 - Database
#
# ## <font color = "purple">General Information</font>
# *** ver github felipeAcamargo
#
# - O tema central do dataset: Empregos e salários na área de Ciência de Dados
#
# - Que tipo de informações ele apresenta: Cargos, departamentos, cidades, salários, modelo de trabalho, tamanho da empresa, nível de experiência
#
# - Onde o banco de dados está disponível: Kaggle - https://www.kaggle.com/datasets/hummaamqaasim/jobs-in-data
#
# *Que tipos de perguntas ou problemas podem ser investigados a partir desse conjunto de dados?
#
# # ⚙️ 2 - Importação e leitura dos dados
#
# Tarefa: Pesquise o conceito de DataFrame em Python, explicando:
#
# - O que é uma estrutura de dados tabular: é um formato composto por linhas e colunas
#
# - Por que o DataFrame é amplamente utilizado em Ciência de Dados: segue a boa prática de cd/python
#
# - Qual biblioteca é necessária para trabalhar com DataFrames: Pandas/Matplot
#
# Discussão: O que o código abaixo faz? :
#
# ```
# 1 import pandas as pd
# 2 df = pd . read_csv (" jobs_in_data . csv ")
# 3 df . head ()
# 4 df . tail ()
# ```
# 1 - importa a biblioteca Pandas e coloca um nome de PD
#
# 2 - faz o carregamento do arquivo csv em memória
#
# 3 - pega os dados iniciais do dataset
#
# 4 - pega os dados do final do dataset
#
# + - como instalar ela no Python
#
# + - qual código para chama-la
#
# # 🔢 3 - Tipos de Variáveis
#
# Tarefa: Pesquise e explique a diferença entre variáveis:
#
# -  Qualitativas (categóricas: nominais e ordinais):
#
# -  Quantitativas (Numéricas: discretas e contínuas):
#
# Discussão: O que o código abaixo faz? :
#
# ```
# 1 df . info ()
# 2 df . dtypes
# ```
#
#
#
# ## Descrição do Conjunto de Dados
#
# ## Informações
#
# ## Objetivo
#
# ## Gráficos

# %% [markdown]
# # ⚙️ 2 - Importação e leitura dos dados
#
# Tarefa: Pesquise o conceito de DataFrame em Python, explicando:
#
# - O que é uma estrutura de dados tabular: é um formato composto por linhas e colunas
#
# - Por que o DataFrame é amplamente utilizado em Ciência de Dados: segue a boa prática de cd/python
#
# - Qual biblioteca é necessária para trabalhar com DataFrames: Pandas/Matplot
#
# Discussão: O que o código abaixo faz? :
#
# ```
# 1 import pandas as pd
# 2 df = pd . read_csv (" jobs_in_data . csv ")
# 3 df . head ()
# 4 df . tail ()
# ```
# 1 - importa a biblioteca Pandas e coloca um nome de PD
#
# 2 - faz o carregamento do arquivo csv em memória
#
# 3 - pega os dados iniciais do dataset
#
# 4 - pega os dados do final do dataset
#
# + - como instalar ela no Python: Pode ser instalado usando o Conda e o comando:
# ```
# pip install pandas
# ```
# + - qual código para chama-la: Basta usar o "import"

# %% [markdown]
# # 🔢 3 - Tipos de Variáveis
# Tarefa: Pesquise e explique a diferença entre variáveis:
#
# Qualitativas (categóricas: nominais e ordinais): variáveis informativas, saber nomes,   (((COLOCAR EXEMPLOS)))
#
# Quantitativas (Numéricas: discretas e contínuas): são variáveis para saber quantidades, tamanhos, informações matemáticas (((COLOCAR EXEMPLOS)))
#
# Discussão: O que o código abaixo faz? :
#
#
# ```
# 1 df . info ()
# 2 df . dtypes
# ```
#
# 1 - descreve o dataset, os tipos de variáveis, os nomes das colunas
#
# 2 - descreve o dataset de forma mais amigável
#
# Descrição do Conjunto de Dados
# Informações
# Objetivo
# Gráficos

# %% [markdown]
# # 🔢 4 - Informações Faltantes e Duplicadas
#
# Tarefa: Pesquise os conceitos de valores nulos e dados duplicadas, explicando por que esses aspectos devem ser analisados em um banco de dados.
#
# - Valores nulos são observações sem dado
#
# - Dados duplicados são observações repeditas, exemplo 2 Justino's cadastrados em "ALUNOS"
#
# Execute o código:
#
# ```
# 1 df . isnull () . sum ()
# 2 df .T. duplicated ()
# ```
#
# 1 - informa a quantidade de observações sem dado
#
# 2 - informa quais variáveis possuem nulidade
#
#
# Discussão:
#
# • Existem valores ausentes no banco de dados? Não
#
# • Como valores nulos podem afetar análises e conclusões? Pode gerar
#
# • Em que situações informações duplicadas podem gerar problemas?

# %% [markdown]
# # 5 - Estatísticas Descritivas
#
# Tarefa: Pesquise o método describe(), explicando:
#
# • Quais estatísticas são calculadas?: contagem geral, médias, menor e maior valores e o
#
# • Para quais tipos de variáveis esse método se aplica? Objetos e numéricas
#
# • Qual o significado de média, mediana, desvio padrão, mínimo e máximo?
#
# - Média, soma dos valores e divido pela quantidade do mesmo
#
# - Mediana é valor central
#
# - Desvio padrão é a diferença entre os extremos e a média
#
# Execute o código:
#
# `1 df . describe ()`
#
# Discussão:
#
# • O que as estatísticas revelam sobre a distribuição dos dados? Há extremos outliers após analisar o boxplot do salário
#
# • Existem indícios de valores extremos (outliers)? Sim, salários que podem ser excluídos numa entrega final
#
# • Por que essa etapa é fundamental antes de análises mais avançadas? Porque pode gerar insights inválidos sobre o cenário salarial

# %% [markdown]
# ## 6 - Padronização e tradução dos nomes das colunas
#
#
# Tarefa: Considere que os resultados desta análise serão apresentados em uma feira aberta à comunidade,
# incluindo pessoas que não possuem familiaridade com termos técnicos em inglês. Traduza os nomes das
# colunas do banco de dados para o português, mantendo clareza, coerência e significado adequado ao
# contexto da Ciência de Dados.
#
# ```
# # Dicionario de traducao dos nomes das colunas
# novos_nomes = {
# " work_year ": " ano_trabalho ",
# " job_title ": " cargo ",
# " job_category ": " categoria_cargo ",
# " salary_currency ": " moeda_salario ",
# " salary ": " salario ",
# " salary_in_usd ": " salario_dolar ",
# " employee_residence ": " residencia_funcionario ",
# " experience_level ": " nivel_experiencia ",
# " employment_type ": " tipo_contrato ",
# " work_setting ": " modelo_trabalho ",
# " company_location ": " localizacao_empresa ",
# " company_size ": " porte_empresa "
# }
#
# # Aplicando a traducao das colunas
# df_pt_br = df . rename ( columns = novos_nomes )
#
# # Exibindo os novos nomes das colunas
# display ( df_pt_br . columns )
# ```
#
# Discussão:
#
# - Por que a tradução dos nomes das colunas é importante ao apresentar dados para o público geral?
#
#   - Para tornar o dados mais apresentável para diversos públicos interessados na informação
#
#
# - Os novos nomes das colunas estão claros para alguém que não conhece programação?
#
#    - Sim
#
# - Algum termo poderia gerar ambiguidade ou confusão? Qual?
#
#   - Job Title/Job Category
#
# - Qual a diferença entre traduzir literalmente e traduzir considerando o contexto?
#
#   - A ideia é tornar mais amigável
#
# - Essa etapa altera os dados do banco ou apenas a forma como eles são apresentados?
#
#   - Altera somente como eles são apresentados
#
# - Como essa padronização contribui para a comunicação dos resultados na feira?
# Perguntas sobre o código:
#
#   - Mitiga as dúvidas em relação à quem produziu o dataset e quem vai consumir
#
# - O que é um dicionário em Python e por que ele é adequado para essa tarefa?
#
#   - Quando o tipo de informação é específica de uma área ocasionando dificuldade no entendimento
#
# - O que faz o método rename(columns=...) do pandas?
#
#   - para atribuir os nomes customizados configurados previamente
#
#
# - O dataframe original é modificado ou um novo dataframe é criado? Explique.
#
#   - um novo dataframe é criado
#
# - Por que é uma boa prática manter os nomes das colunas padronizados em um idioma único?
#   - Isso torna até a disponibilização em múltiplos idiomas mais fácil posteriormente

# %% [markdown]
# ##7 -  Intervalo temporal
#
# Tarefa: Pesquise o módulo datetime em Python e sua importância para análise de dados temporais.
#
# Execute o código:
#
# ```
# df [’ variavel_data_no_banco ’] = pd . to_datetime ( df [’ variavel_data_no_banco ’], format =’%Y’)
# print (" Inicio :", df [’ variavel_data_no_banco ’]. min () )
# print (" Fim:", df [’ variavel_data_no_banco ’]. max () )
# ```
#
# Discussão:
#
# • Qual o período coberto pelo banco de dados?
#
# -
#
# • Por que o intervalo temporal é relevante para análises comparativas?
#
# • Como o contexto histórico pode influenciar os dados?

# %% [markdown]
# #Titulo
# ##Subtítulo
# ###SubSub
#
# ## Banco de Dados
#
# - O tema central do dataset: Empregos e salários na área de Ciência de Dados
#
# - Que tipo de informações ele apresenta: Cargos, departamentos, cidades, salários, modelo de trabalho, tamanho da empresa, nível de experiência
#
# - Tipo: csv
#
# - Onde o banco de dados está disponível: Kaggle - [url](URL "https://www.kaggle.com/datasets/hummaamqaasim/jobs-in-data")
#
# *Que tipos de perguntas ou problemas podem ser investigados a partir desse conjunto de dados?
# O tamanho deste mercado específico, noção dos salários aplicados por região, média salarial por habilidade
#
# ## Descrição do Conjunto de Dados
#
# ## Informações
#
# ## Objetivo
#
# ## Gráficos

# %%
## Jobs and Salaries in Data Science

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount("/ content/drive")

df = pd.read_csv("/content/drive/MyDrive/cdai/jobs_in_data.csv")


df.describe()

df["work_year"] = pd.to_datetime(df["work_year"], format = "%Y")
print(" Inicio :", df["work_year"].min ())
print(" Fim:", df["work_year"].max ())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2805875636.py in <cell line: 0>()
#       6
#       7 from google.colab import drive
# ----> 8 drive.mount("/ content/drive")
#       9
#      10 df = pd.read_csv("/content/drive/MyDrive/cdai/jobs_in_data.csv")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     120
#     121   if ' ' in mountpoint:
# ...
