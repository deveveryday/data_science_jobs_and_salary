# %% [markdown]
# <a href="https://colab.research.google.com/github/deveveryday/data_science_jobs_and_salary/blob/main/project_extensao_060326.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://blossom-cotton-e20.notion.site/Extens-o-30c2805a4c0580fe80cfc0ff8a91b56f

# %% [markdown]
# ## 3.4 Tradução de algumas variáveis categóricas
# A variável experience_level representa uma hierarquia profissional. Para facilitar a comunicação com o público brasileiro, criaremos uma coluna traduzida.
#
# Agora aplique um mapeamento para padronização (tradução da variável categórica) dos níveis de experiência.
#
# Obs.: Mapeamento conceitual, significa associar um conceito de um sistema de representação a outro conceito semanticamente equivalente em outro sistema.
#
# ```
#  nivel_de_experiencia = {
#  "Entry - level ": "Jú nior ",
#  "Mid - level ": " Pleno ",
#  " Senior ": "Sê nior ",
#  " Executive ": " Executivo "
#  }
#
# df_tratado [" experience_level "] = df_tratado [" experience_level "]. map (
# nivel_de_experiencia )
# ```
#
# Discussão:
#
# • O que é um dicionário em Python e qual sua função nesse código?
#
# • O que o método map() realiza?
#
# • O que aconteceria se algum valor não estivesse no dicionário?
#
# • A tradução foi literal ou contextual?
#
# • É recomendável substituir a coluna original? Por quê?

# %% [markdown]
# # Semana 4
#
# # 10. Pesquisar sobre tipos de gráficos e sua relação com os dados
#
# ### **Gráfico de barras**
#
# - **Tipo de variável:** Ideal para variáveis categórica (qualitativa).
# - **Permite visualizar:** frequência ou contagem de cada categoria.
# - **Quando usar:** Para comparar categorias distintas.
# - **Exemplo:**

# %% [markdown]
# ### **Histograma**
#
# - **Tipo de variável:** Ideal para variáveis numérica contínua.
# - **Permite visualizar:** Distribuição dos dados em intervalos (classes).
# - **Quando usar:** Para analisar concentração, assimetria e dispersão.
# - **Exemplo:**

# %% [markdown]
# ### **Gráfico de linhas**
#
# - **Tipo de variável:** Ideal para variáveis numérica ao longo do tempo.
# - **Permite visualizar:** Evolução, tendência e variação temporal.
# - **Quando usar:** Para séries temporais.
# - **Exemplo:**

# %% [markdown]
# ### **Gráfico de pizza**
#
# - **Tipo de variável:** Ideal para variáveis categórica.
# - **Permite visualizar:** Proporção percentual entre categorias.
# - **Quando usar:** Quando há poucas categorias e interesse em participação relativa.
# - **Exemplo:**

# %% [markdown]
# ### ***Boxplot***
#
# - **Tipo de variável:** Ideal para variáveis numérica (comparada entre categorias).
# - **Permite visualizar:** Mediana, quartis, dispersão e outliers.
# - **Quando usar:** Para comparar distribuições entre grupos.
# - **Exemplo:**

# %% [markdown]
# # 11. Gráfico de barras aplicado ao banco de dados
#
# - Utilizado para analisar a variável categórica. Ex.: `job_category`.
# - Justificativa: trata-se de uma variável qualitativa, ideal para comparação de frequências.
# - Permite identificar qual categoria aparece com maior frequência.
# - Facilita a comparação visual entre categorias.
# - Não é adequado para analisar salários diretamente, pois salários são variáveis numéricas contínuas.

# %% [markdown]
# # 12. Histograma aplicado à distribuição salarial
#
# - Aplicado à variável numérica contínua. Ex.: `salary_in_usd`.
# - Permite observar concentração de salários em determinadas faixas.
# - Indica possível assimetria (ex.: concentração em salários menores) e presença de valores extremos.
# - É mais adequado que gráfico de barras porque trabalha com intervalos contínuos.

# %% [markdown]
# # 13. Gráfico de linhas e análise temporal
#
# - Utilizado para analisar a mediana salarial ao longo dos anos (`work_year`).
# - Permite identificar tendência de crescimento, queda ou estabilidade.
# - É adequado para dados organizados cronologicamente.
# - Fatores externos como inflação, mercado de tecnologia e demanda profissional podem influenciar os resultados.

# %% [markdown]
# # 14. Gráfico de pizza e proporções no banco de dados
#
# - Aplicado à variável categórica `work_setting`.
# - Permite visualizar a proporção de cada modelo de trabalho.
# - Funciona bem quando há poucas categorias.
# - Pode não ser adequado quando existem muitas categorias ou diferenças pequenas entre elas.

# %% [markdown]
# # 15. *Boxplot* e análise de dispersão dos salários
#
# - Utilizado para comparar `salary_in_usd` entre níveis de `experience_level`.
# - Mostra mediana, quartis e possíveis *outliers*.
# - Permite verificar variação salarial entre níveis de experiência.
# - Diferente do histograma, facilita a comparação entre grupos simultaneamente.

# %% [markdown]
# # 16. Gráfico de dispersão e relação entre variáveis
#
# - Analisa a relação entre `work_year` e `salary_in_usd`.
# - Permite identificar tendência de crescimento ou dispersão.
# - Indica se há padrão ou ausência de relação.
# - É essencial em análises exploratórias para verificar possíveis correlações.

# %% [markdown]
# # 17. Gráfico adicional e justificativa
#
# **Sugestão:** Gráfico de média salarial por categoria.
#
# - Pode ser feito com:
#
#     ```
#     df.groupby('job_category')['salary_in_usd'].mean().plot(kind='bar')
#     ```
#
# - Justificativa: combina variável categórica com variável numérica.
# - Revela quais categorias possuem maior média salarial.
# - Complementa a análise de frequência com análise de valor médio.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Jobs and Salaries in Data Science

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# To order Dataframes
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/cdai/jobs_in_data.csv")

#teve um crescimento pelos anos
#maioria presencial, remoto na sequencia
#maioria engenheiro, analista, cientista
#estados unidos reino unido e canada dominam
#empresas médias dominam
#fulltime

# %%
#
# nivel_de_experiencia = {
# "Entry - level ": "Jú nior ",
# "Mid - level ": " Pleno ",
# " Senior ": "Sê nior ",
# " Executive ": " Executivo "
# }
#
#df_tratado [" experience_level "] = df_tratado [" experience_level "]. map (
#nivel_de_experiencia )
#

df_handled = df.copy()

new_experience_level = {
    "Entry-level" : "Junior",
    "Mid-level" : "Pleno",
    "Senior": "Sênior",
    "Executive": "Executivo"
}

df_handled = df_handled["experience_level"].map(new_experience_level)

df_handled.head()
# Out:
# 0     Pleno
# 1    Sênior
# 2    Sênior
# 3    Sênior
# 4    Sênior
# Name: experience_level, dtype: object

# %% [markdown]
# Discussão:
#
# • O que é um dicionário em Python e qual sua função nesse código?
# I can quickly view the experience level without dificult
#
# • O que o método map() realiza?
# Make a fast machine replace in the strings
#
# • O que aconteceria se algum valor não estivesse no dicionário?
# Would be by passed
#
# • A tradução foi literal ou contextual?
# Contextual
#
# • É recomendável substituir a coluna original? Por quê?
# Maybe, to compare

# %% [markdown]
# 10. Pesquisar sobre tipos de gráficos e sua relação com os dados
# Tarefa: Pesquise e explique os seguintes tipos de gráficos:
#
# • Gráfico de barras;
#
# • Histograma (distribuição);
#
# • Gráfico de linhas (evolução temporal);
#
# • Gráfico de pizza;
#
# • Boxplot;
#
# • Gráfico de dispersão.
#
# indicando:
#
# • Para quais tipos de variáveis são mais adequados para cada gráfico (categóricas ou numéricas);
#
# • Que tipo de informação cada gráfico permite visualizar;
#
# • Em quais situações o uso do gráfico é mais indicado.
#
# Discussão:
#
# • Qual a importância de relacionar o tipo de gráfico ao tipo de variável?

# %% [markdown]
# • Gráfico de barras: para variáveis qualitativas nominais, quando algo acontece, quantas vezes acontece.

# %%
# Gráfico de barras
# para variáveis qualitativas nominais ou ordinais. quanto aquilo acontece

# frequencia = df [’ experience_level ’]. value_counts ()
#
# plt . bar ( frequencia . index , frequencia . values )
#
# plt . title (" Frequencia por nivel de experiencia ")
# plt . xlabel (" Nivel de experiencia ")
# plt . ylabel (" Quantidade ")
# plt . show ()



o = ['Entry-level', 'Mid-level', 'Senior', 'Executive']

df.describe()

frequency = df["experience_level"].value_counts()


#sns.barplot(x = "experiencie_level", y = "", data = df, order = o)

print(frequency)

plt.bar(frequency.index, frequency.values)

plt.title("Frequency by Experience Level")
plt.xlabel("Level")
plt.ylabel("Income")
plt.show()
# Out:
# experience_level
# Senior         6709
# Mid-level      1869
# Entry-level     496
# Executive       281
# Name: count, dtype: int64

# %%
df.info()

frequency = df["job_title"].value_counts()
#teve um crescimento pelos anos
#maioria presencial, remoto na sequencia
#maioria engenheiro, analista, cientista
#estados unidos reino unido e canada dominam
#empresas médias dominam
#fulltime

#


print(frequency)

plt.bar(frequency.index, frequency.values)

plt.title("Job Title")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB
# job_title
# Data Engineer                2195
# Data Scientist               1989
# Data Analyst                 1388
# ...

# %% [markdown]
# # Barra
# • Qual categoria apresenta maior frequência e qual a possível explicação?
# Senior
#
# • O gráfico de barras facilita a comparação entre categorias? A altura das barra explica claramente quais cargos têm mais remuneração
#
# • Esse gráfico seria adequado para analisar salários? Justifique.
# Sim, bate o olho e já identifica
#
# Análise do código:
#
# • O que a função value_counts() faz na variável experience_level?
#
# • Que tipo de objeto é armazenado na variável frequencia?
#
# • O que representam frequencia.index e frequencia.values no gráfico?
#
# • Qual é a função do comando plt.bar()?
#
# • Para que servem os comandos plt.title(), plt.xlabel() e plt.ylabel()?
#
# • O que acontece se o comando plt.show() não for executado?
#
# • Como poderíamos modificar o código para ordenar as categorias de forma diferente?

# %% [markdown]
# # Histograma (distribuição);

# %%
# Histograma (distribuição);
df.info()
df["salary"].hist( bins =30)

plt.title(" Title ")
plt.xlabel(" x ")
plt.ylabel(" y ")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
plt.figure(figsize = (6,6))

sns.histplot(df["salary"],
             bins=50,
             kde=True,
             color="blue",
             alpha=0.3)

#histplot (df)

# %%
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %% [markdown]
# # 13. Gráfico de linhas e análise temporal

# %%
# 13. Gráfico de linhas e análise temporal

# mediana_salario = df . groupby (’work_year ’) [’ salary_in_usd ’]. median ()
#
# # Cria o grafico de linhas
#7 plt . plot ( mediana_salario . index , mediana_salario . values , marker =’o’)
#8
#9 plt . title (" Mediana Salarial por Ano ")
#10 plt . xlabel (" Ano ")
#11 plt . ylabel (" Salario em USD ")
#12 plt . show ()

df.info()
mean_income = df.groupby("company_size")["salary_in_usd"].median()
plt.plot(mean_income)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# 14. Gráfico de pizza e proporções no banco de dados

# %%
# Calcula a frequencia de cada categoria


# Cria o grafico de pizza
frequency = df["work_setting"].value_counts()
plt.pie(frequency.values, labels = frequency.index, autopct ="%1.1 f%%", startangle =90)
plt.title("Proporcao dos Modelos de Trabalho")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-663/1861202672.py in <cell line: 0>()
#       4 # Cria o grafico de pizza
#       5 frequency = df["work_setting"].value_counts()
# ----> 6 plt.pie(frequency.values, labels = frequency.index, autopct ="%1.1 f%%", startangle =90)
#       7 plt.title("Proporcao dos Modelos de Trabalho")
#       8 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
#df.describe()

#quantitativas: numéricas
##
#discretas: mensuráveis
# salary
#
#contínuas: escala
#
######
#qualitativas: categorias
##
#ordinais: existe uma ordem
#  work_year
#
#nominais: não existe ordenação nem peso
# job_title, job_category, experience_level, employment_type,
#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# **1. Revisão: Tipos de Variáveis**
#
# - Retomar o conceito de tipos de variáveis no *dataset*.
# - Entender como o **Pandas interpreta os tipos de dados**.
#
# ---
#
# **2. Verificação de Cardinalidade**
#
# - Utilizar o comando `.unique()` para:
#     - Identificar **valores únicos** em cada coluna.
#     - Entender a **cardinalidade das variáveis**.
#
# Exemplo:

# %%
print(df["job_title"].unique())
# Out:
# ['Data DevOps Engineer' 'Data Architect' 'Data Scientist'
#  'Machine Learning Researcher' 'Data Engineer' 'Machine Learning Engineer'
#  'Data Analyst' 'Analytics Engineer' 'Applied Scientist' 'BI Developer'
#  'Business Intelligence Engineer' 'Research Scientist' 'Research Analyst'
#  'Research Engineer' 'Data Science Engineer' 'Data Quality Analyst'
#  'Data Product Manager' 'Machine Learning Scientist' 'AI Engineer'
#  'MLOps Engineer' 'Deep Learning Engineer' 'Data Modeler'
#  'Data Product Owner' 'Data Science Consultant'
#  'Business Intelligence Analyst' 'AI Developer' 'Data Manager'
#  'ML Engineer' 'Data Science Director' 'Head of Data' 'BI Analyst'
#  'Data Management Analyst' 'Machine Learning Modeler' 'Data Specialist'
#  'BI Data Analyst' 'Data Integration Engineer'
#  'Business Intelligence Manager' 'Data Integration Specialist'
#  'Data Science Practitioner' 'Business Intelligence Developer'
#  'AI Research Engineer' 'Data Lead' 'Data Management Specialist'
# ...

# %% [markdown]
# **3. Tratamento de Variáveis do Tipo `object`**
#
# - Variáveis `object` são interpretadas de forma **genérica pelo Pandas**.
# - Converter essas variáveis para o tipo **`category`** para:
#     - Melhorar desempenho
#     - Melhorar organização dos dados
#
# Exemplo:

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# ...

# %%
df["job_title"] = df["job_title"].astype("category")
# Out:
# 0           Data DevOps Engineer
# 1                 Data Architect
# 2                 Data Architect
# 3                 Data Scientist
# 4                 Data Scientist
#                   ...
# 9350             Data Specialist
# 9351              Data Scientist
# 9352    Principal Data Scientist
# 9353              Data Scientist
# 9354       Business Data Analyst
# Name: job_title, Length: 9355, dtype: category
# Categories (125, object): ['AI Architect', 'AI Developer', 'AI Engineer', 'AI Programmer', ...,
#                            'Software Data Engineer', 'Staff Data Analyst', 'Staff Data Scientist',
#                            'Staff Machine Learning Engineer']

# %%
from IPython.core import usage
from enum import unique
df.describe(include = "category")


#distribuição e concentração das categorias

df["job_category"].value_counts()
#df["salary_in_usd"]
#experience_level




df.columns
#0. Banco de Dados
#1. Carregamento Pandas
#2. Análise Inicial
#head
#tail
#info
#shape
#dtypes
#columns
#3. Informações sobre as variáveis tipos e tipagem (numérica ou categoricas) .unique
#value_counts()
#select_dtypes(include="type")
#astype("right type")
#memory usage
#4. Informações faltantes e duplicadas.
#5. Estatística Descritiva. Distribuição
#30%NULLS Fail
#6. Gráficos gerais
#7. Particular
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
#1 Evaluate and get sense on dataset

df.head()
df.shape
df.info()
df.describe()
df.columns.tolist()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
#2 Check the NULLS

df.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# 3 - Check UNIQUE values around variables

df.nunique()
# Out:
# work_year                4
# job_title              125
# job_category            10
# salary_currency         11
# salary                1507
# salary_in_usd         1786
# employee_residence      83
# experience_level         4
# employment_type          4
# work_setting             3
# company_location        70
# company_size             3
# dtype: int64

# %%
# 4 - Evaluate variables with data and graphics

# 0   work_year           9355 non-null   int64
# 1   job_title           9355 non-null   category
# 2   job_category        9355 non-null   object
# 3   salary_currency     9355 non-null   object
# 4   salary              9355 non-null   int64
# 5   salary_in_usd       9355 non-null   int64
# 6   employee_residence  9355 non-null   object
# 7   experience_level    9355 non-null   object
# 8   employment_type     9355 non-null   object
# 9   work_setting        9355 non-null   object
# 10  company_location    9355 non-null   object
# 11  company_size        9355 non-null   object

df["job_category"]

job_category_count = df["job_category"].value_counts()



df_clear = df.drop_duplicates().copy()

df_clear.describe(include = ["object", "string", "category"])
# Out:
#                      job_category salary_currency employee_residence  \
# count                        5341            5341               5341
# unique                         10              11                 83
# top     Data Science and Research             USD      United States
# freq                         1655            4707               4255
#
#        experience_level employment_type work_setting company_location  \
# count              5341            5341         5341             5341
# unique                4               4            3               70
# top              Senior       Full-time    In-person    United States
# freq               3444            5296         2913             4301
#
#        company_size
# count          5341
# unique            3
# top               M
# freq           4688

# %%
df_clear.memory_usage(deep = True)
# Out:
# Index                  42728
# work_year              42728
# job_title              18315
# job_category          373324
# salary_currency       277732
# salary                 42728
# salary_in_usd          42728
# employee_residence    326965
# experience_level      300246
# employment_type       309759
# work_setting          302494
# company_location      327306
# company_size          267050
# dtype: int64
